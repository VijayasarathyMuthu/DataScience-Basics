# %% [markdown]
# <a href="https://colab.research.google.com/github/sarathy1988/DataScience-Basics/blob/master/Twitter_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy
# !pip install pandas
# !pip install vaderSentiment
# Out:
# ...
#     100% |████████████████████████████████| 133kB 6.1MB/s
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
#My Twitter API Authentication Variables
consumer_key = 'vNuNSoG6X66EjUNElf84DWfSx'
consumer_secret = 'xXj2SOFVegDpEveTpCraCXkMOGxnEtjCgzVIxEi8VdgQ2TABOX'
access_token = '68405740-tPQCiyU03G9Tz6y0TXLYVoFM0tPVxcqGOapMWyBKV'
access_token_secret = 'olOuYsqltVyXs4Lh4xS6QGJugg8LQjzqZnnFe7uUomxNP'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))

print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @dallenallred: Here's a much more honest ac...
# 1  RT @FDammas: ١- سأتحدث اليوم عن #الذكاء_الاصطن...
# 2  RT @OjoGringo: This is an impressive set of re...
# 3  Artificial Intelligence Is Powerful—And Misund...
# 4  Whichever country leads the way in Artificial ...
# 5  Automation and Artificial Intelligence: How ma...
# 6  RT @sandy_carter: Artificial intelligence” has...
# 7  RT @ajplus: Can algorithms built into artifici...
# 8  RT @ajplus: Can algorithms built into artifici...
# 9  Anthropologist Hu Jiaqi (Jiaqi Hu): Will Artif...
# 2019-02-05 04:49:45

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()

listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)

data['Polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @dallenallred: Here's a much more honest ac...
# 1   RT @FDammas: ١- سأتحدث اليوم عن #الذكاء_الاصطن...
# 2   RT @OjoGringo: This is an impressive set of re...
# 3   Artificial Intelligence Is Powerful—And Misund...
# 4   Whichever country leads the way in Artificial ...
# 5   Automation and Artificial Intelligence: How ma...
# 6   RT @sandy_carter: Artificial intelligence” has...
# 7   RT @ajplus: Can algorithms built into artifici...
# 8   RT @ajplus: Can algorithms built into artifici...
# 9   Anthropologist Hu Jiaqi (Jiaqi Hu): Will Artif...
# 10  Anthropologist Hu Jiaqi (Jiaqi Hu): Will Artif...
# 11  Anthropologist Hu Jiaqi (Jiaqi Hu): Will Artif...
# 12  Anthropologist Hu Jiaqi (Jiaqi Hu): Will Artif...
# 13  Anthropologist Hu Jiaqi (Jiaqi Hu): Will Artif...
# 14  #Google hired gig economy workers to improve a...
# 15  rt @mitsmr\nData Maturity Drives #AI ➔ https:/...
# ...
